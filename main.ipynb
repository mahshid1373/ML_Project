# %% [markdown]
# # HCV data Machine Learning Analysing

# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# ## Cleaning Data

# %% [markdown]
# Import dataset:

# %%
data = pd.read_csv("hcvdat0.csv")

# %%
data
# Out:
#      Unnamed: 0       Category  Age Sex   ALB    ALP    ALT    AST   BIL  \
# 0             1  0=Blood Donor   32   m  38.5   52.5    7.7   22.1   7.5
# 1             2  0=Blood Donor   32   m  38.5   70.3   18.0   24.7   3.9
# 2             3  0=Blood Donor   32   m  46.9   74.7   36.2   52.6   6.1
# 3             4  0=Blood Donor   32   m  43.2   52.0   30.6   22.6  18.9
# 4             5  0=Blood Donor   32   m  39.2   74.1   32.6   24.8   9.6
# ..          ...            ...  ...  ..   ...    ...    ...    ...   ...
# 610         611    3=Cirrhosis   62   f  32.0  416.6    5.9  110.3  50.0
# 611         612    3=Cirrhosis   64   f  24.0  102.8    2.9   44.4  20.0
# 612         613    3=Cirrhosis   64   f  29.0   87.3    3.5   99.0  48.0
# 613         614    3=Cirrhosis   46   f  33.0    NaN   39.0   62.0  20.0
# 614         615    3=Cirrhosis   59   f  36.0    NaN  100.0   80.0  12.0
#
#        CHE  CHOL   CREA    GGT  PROT
# 0     6.93  3.23  106.0   12.1  69.0
# 1    11.17  4.80   74.0   15.6  76.5
# 2     8.84  5.20   86.0   33.2  79.3
# 3     7.33  4.74   80.0   33.8  75.7
# 4     9.15  4.32   76.0   29.9  68.7
# ..     ...   ...    ...    ...   ...
# 610   5.57  6.30   55.7  650.9  68.5
# 611   1.54  3.02   63.0   35.9  71.3
# 612   1.66  3.63   66.7   64.2  82.0
# 613   3.56  4.20   52.0   50.0  71.0
# 614   9.07  5.30   67.0   34.0  68.0
#
# [615 rows x 14 columns]

# %% [markdown]
# Check how many NA valuse do we have in the data:

# %%
data.isna().sum()
# Out:
# Unnamed: 0     0
# Category       0
# Age            0
# Sex            0
# ALB            1
# ALP           18
# ALT            1
# AST            0
# BIL            0
# CHE            0
# CHOL          10
# CREA           0
# GGT            0
# PROT           1
# dtype: int64

# %% [markdown]
# because the number of NAs were not many, so we droped all the rows containing NA value:

# %%
data = data.dropna()

# %%
data.isna().sum()
# Out:
# Unnamed: 0    0
# Category      0
# Age           0
# Sex           0
# ALB           0
# ALP           0
# ALT           0
# AST           0
# BIL           0
# CHE           0
# CHOL          0
# CREA          0
# GGT           0
# PROT          0
# dtype: int64

# %%
data.head()
# Out:
#    Unnamed: 0       Category  Age Sex   ALB   ALP   ALT   AST   BIL    CHE  \
# 0           1  0=Blood Donor   32   m  38.5  52.5   7.7  22.1   7.5   6.93
# 1           2  0=Blood Donor   32   m  38.5  70.3  18.0  24.7   3.9  11.17
# 2           3  0=Blood Donor   32   m  46.9  74.7  36.2  52.6   6.1   8.84
# 3           4  0=Blood Donor   32   m  43.2  52.0  30.6  22.6  18.9   7.33
# 4           5  0=Blood Donor   32   m  39.2  74.1  32.6  24.8   9.6   9.15
#
#    CHOL   CREA   GGT  PROT
# 0  3.23  106.0  12.1  69.0
# 1  4.80   74.0  15.6  76.5
# 2  5.20   86.0  33.2  79.3
# 3  4.74   80.0  33.8  75.7
# 4  4.32   76.0  29.9  68.7

# %% [markdown]
# The "Unnamed: 0" is a repetitive index column, so we drop it:

# %%
data.drop(columns=["Unnamed: 0"], inplace=True)
# Out:
# /var/folders/rv/whttr0rs0h71ygvlwqb00mt00000gp/T/ipykernel_59109/3014202128.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(columns=["Unnamed: 0"], inplace=True)

# %%
data.head()
# Out:
#         Category  Age Sex   ALB   ALP   ALT   AST   BIL    CHE  CHOL   CREA  \
# 0  0=Blood Donor   32   m  38.5  52.5   7.7  22.1   7.5   6.93  3.23  106.0
# 1  0=Blood Donor   32   m  38.5  70.3  18.0  24.7   3.9  11.17  4.80   74.0
# 2  0=Blood Donor   32   m  46.9  74.7  36.2  52.6   6.1   8.84  5.20   86.0
# 3  0=Blood Donor   32   m  43.2  52.0  30.6  22.6  18.9   7.33  4.74   80.0
# 4  0=Blood Donor   32   m  39.2  74.1  32.6  24.8   9.6   9.15  4.32   76.0
#
#     GGT  PROT
# 0  12.1  69.0
# 1  15.6  76.5
# 2  33.2  79.3
# 3  33.8  75.7
# 4  29.9  68.7

# %% [markdown]
# Check if the data type of all columns are correct:

# %%
data.dtypes
# Out:
# Category     object
# Age           int64
# Sex          object
# ALB         float64
# ALP         float64
# ALT         float64
# AST         float64
# BIL         float64
# CHE         float64
# CHOL        float64
# CREA        float64
# GGT         float64
# PROT        float64
# dtype: object

# %% [markdown]
# Transform the "AgeGroup" column into differernt bins and make it numerical:

# %%
data['AgeGroup'] = pd.cut(data['Age'], bins=[0, 18, 35, 50, 65, 100], labels=[0, 1, 2, 3, 4])
data['AgeGroup'] = data['AgeGroup'].astype('int64')
# Out:
# /var/folders/rv/whttr0rs0h71ygvlwqb00mt00000gp/T/ipykernel_59109/3190028697.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['AgeGroup'] = pd.cut(data['Age'], bins=[0, 18, 35, 50, 65, 100], labels=[0, 1, 2, 3, 4])
# /var/folders/rv/whttr0rs0h71ygvlwqb00mt00000gp/T/ipykernel_59109/3190028697.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['AgeGroup'] = data['AgeGroup'].astype('int64')

# %%
data.head()
# Out:
#         Category  Age Sex   ALB   ALP   ALT   AST   BIL    CHE  CHOL   CREA  \
# 0  0=Blood Donor   32   m  38.5  52.5   7.7  22.1   7.5   6.93  3.23  106.0
# 1  0=Blood Donor   32   m  38.5  70.3  18.0  24.7   3.9  11.17  4.80   74.0
# 2  0=Blood Donor   32   m  46.9  74.7  36.2  52.6   6.1   8.84  5.20   86.0
# 3  0=Blood Donor   32   m  43.2  52.0  30.6  22.6  18.9   7.33  4.74   80.0
# 4  0=Blood Donor   32   m  39.2  74.1  32.6  24.8   9.6   9.15  4.32   76.0
#
#     GGT  PROT  AgeGroup
# 0  12.1  69.0         1
# 1  15.6  76.5         1
# 2  33.2  79.3         1
# 3  33.8  75.7         1
# 4  29.9  68.7         1

# %% [markdown]
# Transform the "Sex" column from categorical to numerical:

# %%
data["Sex"].unique()
# Out:
# array(['m', 'f'], dtype=object)

# %%
data['Sex'] = data['Sex'].map({'m': 0,'f': 1})
data.head()
# Out:
# /var/folders/rv/whttr0rs0h71ygvlwqb00mt00000gp/T/ipykernel_59109/1104970521.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Sex'] = data['Sex'].map({'m': 0,'f': 1})
#         Category  Age  Sex   ALB   ALP   ALT   AST   BIL    CHE  CHOL   CREA  \
# 0  0=Blood Donor   32    0  38.5  52.5   7.7  22.1   7.5   6.93  3.23  106.0
# 1  0=Blood Donor   32    0  38.5  70.3  18.0  24.7   3.9  11.17  4.80   74.0
# 2  0=Blood Donor   32    0  46.9  74.7  36.2  52.6   6.1   8.84  5.20   86.0
# 3  0=Blood Donor   32    0  43.2  52.0  30.6  22.6  18.9   7.33  4.74   80.0
# 4  0=Blood Donor   32    0  39.2  74.1  32.6  24.8   9.6   9.15  4.32   76.0
#
#     GGT  PROT  AgeGroup
# 0  12.1  69.0         1
# 1  15.6  76.5         1
# 2  33.2  79.3         1
# 3  33.8  75.7         1
# 4  29.9  68.7         1

# %% [markdown]
# The "Category" column is our Target column. so we want to make sure how to categorize it in the best form.

# %%
data["Category"].unique()
# Out:
# array(['0=Blood Donor', '0s=suspect Blood Donor', '1=Hepatitis',
#        '2=Fibrosis', '3=Cirrhosis'], dtype=object)

# %%
data["Category"].value_counts()
# Out:
# 0=Blood Donor             526
# 3=Cirrhosis                24
# 1=Hepatitis                20
# 2=Fibrosis                 12
# 0s=suspect Blood Donor      7
# Name: Category, dtype: int64

# %%
# data['Category'] = data['Category'].map({'Blood Donor': 0,'f': 1})
# data.head()
